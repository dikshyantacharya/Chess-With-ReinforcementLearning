# %%
#!pip install chess
import chess
import csv
import numpy as np
import tensorflow as tf
from keras import layers, models
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Conv2D, Flatten, Input, Concatenate
import random
import keras
from keras.layers import Input
import pandas as pd
import numpy as np
import ast  # To safely evaluate strings containing Python literals
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
from keras.losses import CategoricalCrossentropy, MeanSquaredError
import random

# %%
board = chess.Board()
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
def board_to_input(board):
    # Define a mapping for pieces to integers
    piece_to_value = {
        (chess.PAWN, chess.WHITE): 1,
        (chess.KNIGHT, chess.WHITE): 2,
        (chess.BISHOP, chess.WHITE): 3,
        (chess.ROOK, chess.WHITE): 4,
        (chess.QUEEN, chess.WHITE): 5,
        (chess.KING, chess.WHITE): 6,
        (chess.PAWN, chess.BLACK): 7,
        (chess.KNIGHT, chess.BLACK): 8,
        (chess.BISHOP, chess.BLACK): 9,
        (chess.ROOK, chess.BLACK): 10,
        (chess.QUEEN, chess.BLACK): 11,
        (chess.KING, chess.BLACK): 12
    }

    # 8x8 grid with 14 channels: 12 for pieces, 1 for castling rights, 1 for side to move
    board_representation = np.zeros((8, 8, 17), dtype=int)

    # Fill the board representation with values for each piece
    for square in chess.SQUARES:
        rank = chess.square_rank(square)
        file = chess.square_file(square)
        piece = board.piece_at(square)
        if piece is not None:
            value = piece_to_value.get((piece.piece_type, piece.color))
            board_representation[rank, file, value - 1] = 1

    # Castling rights and side to move
    castling_rights_white_kingside = int(board.has_kingside_castling_rights(chess.WHITE))
    castling_rights_white_queenside = int(board.has_queenside_castling_rights(chess.WHITE))
    castling_rights_black_kingside = int(board.has_kingside_castling_rights(chess.BLACK))
    castling_rights_black_queenside = int(board.has_queenside_castling_rights(chess.BLACK))
    side_to_move = int(board.turn == chess.WHITE)

    # Add castling rights and side to move to the last two channels uniformly
    board_representation[:, :, 12] = castling_rights_white_kingside
    board_representation[:, :, 13] = castling_rights_white_queenside
    board_representation[:, :, 14] = castling_rights_black_kingside
    board_representation[:, :, 15] = castling_rights_black_queenside
    board_representation[:, :, 16] = side_to_move

    return board_representation

# %%
def create_dual_output_model():
    # Input layer
    inputs = Input(shape=(8, 8, 17))

    # Common convolutional layers
    x = Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same')(inputs)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = Flatten()(x)

    # Shared dense layer
    shared_dense = Dense(50, activation='relu')(x)
    dropout = Dropout(0.5)(shared_dense)

    # Policy head
    policy_dense = Dense(4672, activation='softmax', name='policy_output')(dropout)

    # Value head - adjusting to output between 0 and 1 as per your requirement
    value_dense = Dense(1, activation='sigmoid', name='value_output')(dropout) # Using sigmoid to get output between 0 and 1

    # Create the dual output model
    model = Model(inputs=inputs, outputs=[policy_dense, value_dense])

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),
                  loss={'policy_output': 'categorical_crossentropy', 'value_output': 'mean_squared_error'},
                  metrics={'policy_output': 'accuracy', 'value_output': 'mse'})

    return model

# Create the model
model = create_dual_output_model()

# Print model summary to verify architecture
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 8, 8, 17)]           0         []
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 32)             4928      ['input_3[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 64)             18496     ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 64)             36928     ['conv2d_7[0][0]']
#
#  flatten_2 (Flatten)         (None, 4096)                 0         ['conv2d_8[0][0]']
#
#  dense_2 (Dense)             (None, 50)                   204850    ['flatten_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 50)                   0         ['dense_2[0][0]']
#
#  policy_output (Dense)       (None, 4672)                 238272    ['dropout_2[0][0]']
#
#  value_output (Dense)        (None, 1)                    51        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 503525 (1.92 MB)
# Trainable params: 503525 (1.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
"""def select_move_optimized(probabilities, board, exploration_rate=0.1):
    valid_moves_indices = [move_to_index(move, board) for move in board.legal_moves]
    if not valid_moves_indices:
        raise ValueError("No valid moves available.")

    # Filter out probabilities for valid moves only and their indices
    valid_probs_with_indices = [(i, probabilities[i]) for i in valid_moves_indices if probabilities[i] > 0]

    # Exploration vs Exploitation decision
    if random.random() < exploration_rate:
        # Exploration: Randomly choose among valid moves with non-zero probability
        chosen_index = random.choice(valid_probs_with_indices)[0]
    else:
        # Exploitation: Choose the move with the highest probability among valid moves
        chosen_index = max(valid_probs_with_indices, key=lambda x: x[1])[0]

    # Convert the chosen index back to the move
    chosen_move = index_to_move(chosen_index, board)
    print(chosen_move)
    return chosen_move
"""
# Exploitation of 90% of visited game exploration of 5% of time
def select_highest_probability_move_with_exploration(probabilities, board, exploration_rate=0.15):
    valid_moves = list(board.legal_moves)
    if not valid_moves:
        raise ValueError("No valid moves available.")

    # Create a list of (move, probability) tuples for all valid moves
    valid_moves_with_probs = [(move, probabilities[move_to_index(move, board)]) for move in valid_moves]

    # Sort the valid moves based on their probabilities in descending order
    valid_moves_with_probs.sort(key=lambda x: x[1], reverse=True)

    # Determine whether to explore or exploit based on the exploration rate
    if random.random() < exploration_rate:
        top_n = max(1, int(len(valid_moves_with_probs) * exploration_rate))
        chosen_move = random.choice(valid_moves_with_probs[:top_n])[0]
    else:
        # Exploitation: Choose the valid move with the highest probability
        chosen_move = valid_moves_with_probs[0][0]

    return chosen_move

# %%
def calculate_knight_to_square(from_square, direction):
    # Mapping direction to board movements for a knight
    knight_moves = {
        0: (-2, -1),  # North Left
        1: (-2, 1),   # North Right
        2: (-1, 2),   # East Up
        3: (1, 2),    # East Down
        4: (2, 1),    # South Right
        5: (2, -1),   # South Left
        6: (1, -2),   # West Down
        7: (-1, -2)   # West Up
    }
    move = knight_moves[direction]
    from_row, from_col = divmod(from_square, 8)
    to_row = from_row + move[0]
    to_col = from_col + move[1]

    # Ensure the move stays within the bounds of the chessboard
    if 0 <= to_row < 8 and 0 <= to_col < 8:
        return chess.square(to_col, to_row)
    else:
        print("invalid knight")
        return None  # This indicates an invalid move

# %%
def calculate_queenlike_to_square(from_square, direction, distance):
    # Mapping direction to board movements for a queen
    queen_directions = {
        0: (-1, -1),  # Northwest
        1: (-1, 0),   # North
        2: (-1, 1),   # Northeast
        3: (0, 1),    # East
        4: (1, 1),    # Southeast
        5: (1, 0),    # South
        6: (1, -1),   # Southwest
        7: (0, -1)    # West
    }
    move = queen_directions[direction]
    from_row, from_col = divmod(from_square, 8)
    to_row = from_row + move[0] * distance
    to_col = from_col + move[1] * distance

    # Ensure the move stays within the bounds of the chessboard
    if 0 <= to_row < 8 and 0 <= to_col < 8:
        return chess.square(to_col, to_row)
    else:
        print("invalid queen")
        return None  # This indicates an invalid move

# %%
def calculate_underpromotion_to_square(from_square, promotion_category, direction, is_white_turn):
    # Assuming direction: 0 = forward, 1 = left diagonal, 2 = right diagonal
    # promotion_category is not directly used here but can determine the piece to promote to
    direction_mapping = {
        0: (-1, 0),  # Forward (for white, reverse for black)
        1: (-1, -1), # Left Diagonal (for white, reverse for black)
        2: (-1, 1)   # Right Diagonal (for white, reverse for black)
    }

    if not is_white_turn:  # If it's black's turn, reverse the direction
        direction_mapping = {
            0: (1, 0),  # Forward
            1: (1, 1),  # Left Diagonal (from black's perspective)
            2: (1, -1)  # Right Diagonal
        }

    move = direction_mapping[direction]
    from_row, from_col = divmod(from_square, 8)
    to_row = from_row + move[0]
    to_col = from_col + move[1]

    # Ensure the move stays within the bounds of the chessboard
    if 0 <= to_row < 8 and 0 <= to_col < 8:
        to_square = chess.square(to_col, to_row)
        # Determine the promotion piece based on the category
        promotion_piece = None
        if promotion_category == 0:  # Knight
            promotion_piece = chess.KNIGHT
        elif promotion_category == 1:  # Bishop
            promotion_piece = chess.BISHOP
        elif promotion_category == 2:  # Rook
            promotion_piece = chess.ROOK
        return to_square, promotion_piece
    else:
        print("invalid promotion")
        return None, None  # This indicates an invalid move or invalid promotion

# %%
def move_to_index(move, board):
    from_square = move.from_square
    to_square = move.to_square

    piece = board.piece_at(from_square)
    if piece is None:
        raise ValueError("No piece at the from_square.")

    from_row, from_col = divmod(from_square, 8)
    to_row, to_col = divmod(to_square, 8)

    index = None

    if piece.piece_type == chess.KNIGHT:
        direction = calculate_knight_move_direction(from_row, from_col, to_row, to_col)
        index = from_square * 73 + direction  # Incorporating from_square into the index
    elif piece.piece_type == chess.KING:
        # Similar adjustments for king, including castling
        if board.is_castling(move):
            index = from_square * 73 + 64 + (0 if move.to_square in [chess.G1, chess.G8] else 1)
        else:
            direction, distance = calculate_queenlike_move_direction_and_distance(from_row, from_col, to_row, to_col)
            index = from_square * 73 + 64 + 2 + direction  # Example adjustment
    elif piece.piece_type in [chess.QUEEN, chess.BISHOP, chess.ROOK, chess.PAWN] and not move.promotion:
        direction, distance = calculate_queenlike_move_direction_and_distance(from_row, from_col, to_row, to_col)
        index = from_square * 73 + direction * 8 + (distance - 1)
    elif move.promotion:
        if move.promotion != chess.QUEEN:
            promotion_category, direction = calculate_underpromotion_category_and_direction(move, board)
            index = from_square * 73 + 64 + 3 + promotion_category * 3 + direction
        else:
            direction, distance = calculate_queenlike_move_direction_and_distance(from_row, from_col, to_row, to_col)
            index = from_square * 73 + direction * 8 + (distance - 1)

    if index is None:
        print("Move is ", move)
        raise ValueError("Could not determine move index.")

    return index

# %%
def calculate_to_square_from_direction_and_distance(board, from_square, direction, distance):
    # Identify the piece at the from_square
    piece = board.piece_at(from_square)
    if piece is None:
        raise ValueError("No piece at the from_square.")

    # Determine the calculation based on the piece type
    if piece.piece_type == chess.KNIGHT:
        # Use the knight-specific calculation
        return calculate_knight_to_square(from_square, direction)
    elif piece.piece_type in [chess.QUEEN, chess.ROOK, chess.BISHOP]:
        # Use the queen-like calculation for these pieces
        return calculate_queenlike_to_square(from_square, direction, distance)
    else:
        # Optionally handle other pieces or raise an error
        raise ValueError(f"Unsupported piece type for this calculation: {piece.symbol()}")

# %%
def index_to_move(index, board):
    # Extract from_square by dividing the index by 73
    from_square = index // 73
    move_detail_index = index % 73  # Remainder contains move details

    # Initialize variables
    to_square = None
    promotion = None

    piece = board.piece_at(from_square)
    if piece is None:
        raise ValueError("No piece at the calculated from_square.")

    # Determine the move based on the piece type and move details
    if piece.piece_type == chess.KNIGHT:
        # Decode knight move
        direction = move_detail_index
        to_square = calculate_knight_to_square(from_square, direction)
    elif piece.piece_type == chess.KING and move_detail_index >= 64:
        # Decode castling or king move
        if move_detail_index == 64:  # Kingside castling
            to_square = chess.G1 if from_square < 8 else chess.G8
        elif move_detail_index == 65:  # Queenside castling
            to_square = chess.C1 if from_square < 8 else chess.C8
        else:
            # Standard king move (not implemented here, requires additional logic)
            pass
    else:
        # Decode queen-like moves (including pawns for simplicity)
        direction = (move_detail_index // 8) % 8
        distance = (move_detail_index % 8) + 1
        to_square = calculate_queenlike_to_square(from_square, direction, distance)

    # Check for promotion (not fully implemented here, requires additional logic)
    if piece.piece_type == chess.PAWN and (to_square // 8 == 0 or to_square // 8 == 7):
        promotion = chess.QUEEN  # Simplified, actual promotion might vary

    # Construct the move
    if to_square is not None:
        move = chess.Move(from_square, to_square, promotion=promotion)
        if move in board.legal_moves:
            return move
    print("index_to_move")
    return None  # In case no valid move was found

# %%
def calculate_queenlike_move_direction_and_distance(from_row, from_col, to_row, to_col):
    delta_row = to_row - from_row
    delta_col = to_col - from_col

    direction = None
    distance = max(abs(delta_row), abs(delta_col))

    if delta_row == 0 and delta_col > 0:
        direction = 3  # East
    elif delta_row == 0 and delta_col < 0:
        direction = 7  # West
    elif delta_row > 0 and delta_col == 0:
        direction = 5  # South
    elif delta_row < 0 and delta_col == 0:
        direction = 1  # North
    elif delta_row > 0 and delta_col > 0:
        direction = 4  # Southeast
    elif delta_row < 0 and delta_col < 0:
        direction = 0  # Northwest
    elif delta_row > 0 and delta_col < 0:
        direction = 6  # Southwest
    elif delta_row < 0 and delta_col > 0:
        direction = 2  # Northeast

    return direction, distance

# %%
def calculate_knight_move_direction(from_row, from_col, to_row, to_col):
    row_diff = to_row - from_row
    col_diff = to_col - from_col

    # Define all possible knight moves
    knight_moves = {
        (-2, -1): 0,
        (-2, 1): 1,
        (-1, 2): 2,
        (1, 2): 3,
        (2, 1): 4,
        (2, -1): 5,
        (1, -2): 6,
        (-1, -2): 7
    }

    return knight_moves.get((row_diff, col_diff))

# %%
def calculate_underpromotion_category_and_direction(move, board):
    from_square = move.from_square
    to_square = move.to_square

    from_row, from_col = divmod(from_square, 8)
    to_row, to_col = divmod(to_square, 8)

    delta_row = to_row - from_row
    delta_col = to_col - from_col

    direction = None
    if delta_col == 0:
        direction = 0  # Forward
    elif delta_col == 1:
        direction = 2  # Right Diagonal
    elif delta_col == -1:
        direction = 1  # Left Diagonal

    # Determine the promotion category based on the promoted piece type
    if move.promotion == chess.KNIGHT:
        promotion_category = 0
    elif move.promotion == chess.BISHOP:
        promotion_category = 1
    elif move.promotion == chess.ROOK:
        promotion_category = 2
    else:
        raise ValueError("Invalid promotion piece.")

    return promotion_category, direction

# %%
def index_to_uci(index, board):
    return index
    index = int(index)  # Ensure index is an integer
    square = index % 64  # Find the square involved
    category = index // 64  # Determine the category of move

    # Convert square index to board position
    from_row, from_col = divmod(square, 8)
    from_square = chess.square(from_col, from_row)

    to_square = None
    promotion_piece = None

    if category < 56:  # Queen-like moves
        direction = category // 7
        distance = category % 7 + 1
        to_square = calculate_queenlike_to_square(from_square, direction, distance)
    elif category < 64:  # Knight moves
        direction = category - 56
        to_square = calculate_knight_to_square(from_square, direction)
    else:  # Underpromotions
        promotion_category = (category - 64) // 3
        direction = (category - 64) % 3
        to_square, promotion_piece = calculate_underpromotion_to_square(from_square, promotion_category, direction, board.turn)

    if to_square is None:
        raise ValueError("Could not calculate destination square.")

    move = chess.Move(from_square, to_square, promotion=promotion_piece)

    if move not in board.legal_moves:
        raise ValueError(f"Generated move {move.uci()} is not legal in the current board state.")

    return move.uci()

# %%
def play_game(board, model):
    # Convert the board to the input format expected by the model
    board_input = board_to_input(board)
    # Predict the policy (move probabilities) and value from the current board state
    policy, value = model.predict(board_input[np.newaxis, :], verbose=0)  # Adding batch dimension

    valid_move_mask = np.zeros_like(policy[0])  # Initialize a mask of zeros
    for move in board.legal_moves:
        valid_move_mask[move_to_index(move, board)] = 1  # Set valid move positions to 1

    # Apply the mask to zero out invalid move probabilities
    masked_policy = policy[0] * valid_move_mask

    # Renormalize probabilities (to ensure they sum to 1)
    masked_policy /= np.sum(masked_policy)

    # Adjust move selection strategy based on whose turn it is
    move = select_highest_probability_move_with_exploration(masked_policy, board)

    # Execute the move on the board
    uci_move = index_to_uci(move, board)  # Convert the selected move index to UCI format

    board.push(move)  # Make the move

    return board, masked_policy, uci_move, board_input  # Return the updated board, chosen policy, and UCI move

# %%
def calculate_total_value(board):
    # Assign values to each piece type
    piece_values = {
        chess.PAWN: 1,
        chess.KNIGHT: 3,
        chess.BISHOP: 3,
        chess.ROOK: 5,
        chess.QUEEN: 9
    }

    white_value = 0
    black_value = 0

    # Iterate over all squares
    for square in chess.SQUARES:
        piece = board.piece_at(square)
        if piece is not None:
            # Add the value of the piece to either white_value or black_value based on the piece color
            if piece.color == chess.WHITE:
                white_value += piece_values.get(piece.piece_type, 0)
            else:
                black_value += piece_values.get(piece.piece_type, 0)

    # Subtract black's total value from white's total value
    net_value = white_value - black_value
    return net_value

# %%
def assign_values(game_data, result, board, base_discount_factor=0.05):
    display(board)
    # Determine the initial outcome based on the game result
    if result == "1-0":
        outcome = 1  # White win
    elif result == "0-1":
        outcome = -1  # Black win
    else:
        board_value = calculate_total_value(board)
        print("Board_value is: ", board_value)
        if board_value >= 5:
            outcome = 0.25
        elif board_value <= -5:
            outcome = -0.25
        else:
            outcome = 0  # Draw or other cases

    num_moves = len(game_data)
    # Apply a linear scaling for the discount to ensure a smooth transition
    if outcome != 0:
        for i in range(num_moves):
            # Calculate a linearly scaled discount factor that starts near 0 for the first move
            # and approaches 1 for the last move, ensuring the final move reflects the actual outcome
            linear_scale = (i + 1) / num_moves
            game_data[i][-1] = outcome * linear_scale
    else:  # For draws, assign the outcome directly without discount
        for item in game_data:
            item[-1] = outcome

# %%
def generateData(number_of_games):
    all_games_data = []  # Collect data from all games
    model = create_dual_output_model()
    for game_number in range(1, number_of_games + 1):
        board = chess.Board()
        game_data = []
        while not board.is_game_over(claim_draw=True):
            board, policy, uci_move, board_input = play_game(board, model)
            game_data.append([board_input, policy, None])
        assign_values(game_data, board.result(), board)
        all_games_data.append(game_data)
        print(f"Game {game_number} finished.")
    save_game_data(all_games_data)
    print("All games completed.")

# %%
def save_game_data(all_games_data, file_name="game_data.csv"):
    # Open the CSV file for writing
    with open(file_name, mode='w', newline='') as file:
        writer = csv.writer(file)

        # Write the header row
        writer.writerow(['chess position', 'policy head', 'value head'])

        # Temporarily set numpy print options to ensure full array serialization
        np.set_printoptions(threshold=np.inf)

        # Iterate over all games data
        for game_data in all_games_data:
            # Iterate over each move in the game_data
            for move in game_data:
                # Ensure move[0] (board_input) is a numpy array
                if not isinstance(move[0], np.ndarray):
                    move[0] = np.array(move[0])

                # Serialize the board position and policy to strings without abbreviation
                board_str = np.array2string(move[0], separator=',').replace('\n', '').replace(' ', '').replace('[[', '[').replace(']]', ']')
                policy_str = np.array2string(move[1], separator=',').replace('\n', '').replace(' ', '')
                outcome = move[2]  # Outcome is already in the correct format

                # Write the move data to the CSV file
                writer.writerow([board_str, policy_str, outcome])

        # Reset numpy print options to default
        np.set_printoptions(threshold=1000)

# %%
def prepare_data(file_path = "game_data.csv"):
    # Load the dataset
    df = pd.read_csv(file_path)

    # Convert the string representations back to arrays
    df['chess position'] = df['chess position'].apply(ast.literal_eval)
    df['policy head'] = df['policy head'].apply(ast.literal_eval)

    # Reshape the chess position data from (64, 17) to (8, 8, 17)
    X = np.array([np.array(pos).reshape(8, 8, 17) for pos in df['chess position'].tolist()])
    Y_policy = np.array(df['policy head'].tolist())  # Policy labels
    Y_value = df['value head'].values  # Value labels

    return X, Y_policy, Y_value

# %%
def train_model(model, epochs, batch_size, learning_rate):
    # Load and prepare the data
    X, Y_policy, Y_value = prepare_data()

    # Split the data into training and validation sets
    X_train, X_val, Y_policy_train, Y_policy_val, Y_value_train, Y_value_val = train_test_split(
        X, Y_policy, Y_value, test_size=0.2, random_state=42)

    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss={'policy_output': CategoricalCrossentropy(), 'value_output': MeanSquaredError()},
                  metrics={'policy_output': 'accuracy', 'value_output': 'mse'})

    # Train the model
    history = model.fit(X_train, {'policy_output': Y_policy_train, 'value_output': Y_value_train},
                        validation_data=(X_val, {'policy_output': Y_policy_val, 'value_output': Y_value_val}),
                        epochs=epochs, batch_size=batch_size)

    model.save('chess_model.h5')
    return history

# %%
generateData(100)
# Out:
# Board('1nb3n1/4k3/1R2p3/p3pp2/3p3p/8/6PP/RN3K2 b - - 11 68')
# Board_value is:  0
# Game 1 finished.
# Board('rnb1kbnr/1pqppp1p/p7/2p1B3/8/1P6/P1PPPPPP/RN1QKBNR w KQkq - 7 8')
# Board_value is:  1
# Game 2 finished.
# Board('2bq1bk1/2pnpnB1/rp1pB3/p7/P3P2p/NP6/2PPNPP1/R2Q1K1R w - - 15 33')
# Board_value is:  6
# Game 3 finished.
# Board('rnb2bn1/3pp3/1p4k1/P1p3Bp/8/1P2P1P1/N1PP1PP1/RN1Q1KR1 w - - 15 25')
# Board_value is:  14
# Game 4 finished.
# Board('rnbqkbn1/1p1pppBp/p7/2p5/8/NP6/P1PPPPPP/R2QKBNR w KQq - 9 11')
# Board_value is:  6
# Game 5 finished.
# Board('rnb1kbnr/3ppp2/1p6/2p2K2/p5pp/N3P2P/PPPP1P2/R1BQ2NR b kq - 7 17')
# Board_value is:  5
# Game 6 finished.
# Board('1n3Bn1/3pp2k/b7/p1p5/4P2p/N7/P1PPN2P/R2Q1K2 b - - 7 47')
# Board_value is:  14
# Game 7 finished.
# Board('rnbqkbnB/1p1ppp1p/8/p1p5/8/NP6/P1PPPPPP/R2QKBNR w KQq - 11 12')
# Board_value is:  6
# Game 8 finished.
# Board('1nB4B/5p2/1k2p3/2p5/p6p/8/6P1/R3bKR1 b - - 11 73')
# Board_value is:  6
# Game 9 finished.
# Board('1nb1k1n1/3p1p2/1p1bpB2/2p5/p3P3/3r3p/P1PPNP1P/RN1Q1KR1 b - - 7 33')
# Board_value is:  10
# Game 10 finished.
# Board('rnbqkbn1/3ppp1p/1p3B2/p1p5/2B5/NP2P3/P1PPNPPP/R2Q1KR1 w q - 8 23')
# Board_value is:  6
# Game 11 finished.
# Board('1n4n1/8/6kb/4p3/p6p/N7/P2PK2P/R7 w - - 18 72')
# Board_value is:  -1
# Game 12 finished.
# Board('rnb1kbn1/1pqppp1p/p7/2p1B3/8/NP6/P1PPPPPP/R2QKBNR w KQq - 18 18')
# Board_value is:  6
# Game 13 finished.
# Board('rnb1kbn1/1pqpppB1/p7/2p5/7p/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 14 finished.
# Board('3q1b1r/1B2pn2/3k1nR1/2p2p2/p6p/NP5P/N1PP1P2/R2Q1K2 b - - 25 39')
# Board_value is:  5
# Game 15 finished.
# Board('1nb1k1n1/1B1pbp2/1p3B2/2p1pQ2/8/P3P1p1/3P1PP1/1N2NK1R w - - 15 48')
# Board_value is:  13
# Game 16 finished.
# Board('rnb1kbn1/1pqpppB1/p7/2p5/7p/NP6/P1PPPPPP/R2QKBNR w KQq - 22 18')
# Board_value is:  6
# Game 17 finished.
# Board('1n3b2/4pp1B/1pk4n/2p1p3/7p/NP2P3/P1PPQP1P/R5KR b - - 26 67')
# Board_value is:  17
# Game 18 finished.
# Board('rnb1kbn1/1p1ppp2/q7/2p1B2p/2P1P3/1P3N2/P2P1PPP/RN1Q1K1R w q - 11 21')
# Board_value is:  4
# Game 19 finished.
# Board('1n2kb2/3ppp2/b7/pNpBQ3/4R3/4P3/P2P1P1P/R2N1K2 w - - 21 75')
# Board_value is:  19
# Game 20 finished.
# Board('1nb1kbn1/1p1ppp2/6r1/2p1B3/p6p/Nq6/P1PPPP1P/R2QKBNR b KQ - 15 34')
# Board_value is:  4
# Game 21 finished.
# Board('1nB1k1n1/3p1p2/8/2p1p3/p6p/NP2P3/PbQ1KPPP/6R1 w - - 7 45')
# Board_value is:  11
# Game 22 finished.
# Board('1nb1k1n1/3p1p2/1pp1p3/4B3/8/PP2P1K1/2PP4/RN1QR3 w - - 24 50')
# Board_value is:  16
# Game 23 finished.
# Board('rnb1kbnR/3p1p2/1p2pB2/P1p5/8/N3P3/P1PPNP1P/R2Q1K2 w - - 7 42')
# Board_value is:  13
# Game 24 finished.
# Board('rnb2bn1/3ppk2/1p3B2/1Np5/8/1P2P3/N4PPP/3q1KR1 w - - 0 29')
# Game 25 finished.
# Board('8/8/1p1ppk2/2p5/p2n1K2/NP1N2P1/P2P1P2/R5R1 b - - 43 96')
# Board_value is:  13
# Game 26 finished.
# Board('rnb1kbn1/1pqpppBp/p7/2p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 27 finished.
# Board('rnbqkbn1/1p1pppBp/p7/2p5/8/NP6/P1PPPPPP/R2QKBNR w KQq - 15 15')
# Board_value is:  6
# Game 28 finished.
# Board('8/4pp2/3k4/p1pn1K2/7P/7P/5P2/1n6 b - - 23 87')
# Board_value is:  -7
# Game 29 finished.
# Board('B1b5/8/1p2p3/b1p1Q3/8/Nk4KP/5P1P/R7 w - - 30 65')
# Board_value is:  14
# Game 30 finished.
# Board('1nb3nB/3pkp2/1p6/2p5/p1B1P2p/N6r/P1PP1PKP/R2Q2NR w - - 25 49')
# Board_value is:  17
# Game 31 finished.
# Board('1nb2bnq/4kp2/1p2p3/r1p5/P6p/NQN1P3/P4PPP/5KR1 b - - 13 48')
# Board_value is:  -5
# Game 32 finished.
# Board('4n3/5N2/1pk5/p1p5/P5P1/NP1K4/2PP4/8 w - - 15 90')
# Board_value is:  5
# Game 33 finished.
# Board('rnb2bn1/3pp3/1p4k1/p1p1B1q1/P3P2p/1P6/N1PP1PPP/RN1Q1K1R w - - 34 31')
# Board_value is:  4
# Game 34 finished.
# Board('rnbqkbn1/1p1pppBp/p7/2p5/8/NP6/P1PPPPPP/R2QKBNR w KQq - 15 15')
# Board_value is:  6
# Game 35 finished.
# Board('1nB1k1N1/3p1p2/1p2p3/r7/3p4/8/5P1P/b4K2 b - - 11 84')
# Board_value is:  -8
# Game 36 finished.
# Board('rnbqkbn1/1p1pppBp/8/p1p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 37 finished.
# Board('rnbqkbnB/1p1ppp2/8/p1p5/7p/1P6/P1PPPPPP/RN1QKBNR w KQq - 16 16')
# Board_value is:  6
# Game 38 finished.
# Board('rnbqkbn1/1p1ppp2/p1B5/P1p1B2p/4P3/1P6/2PP1PPP/RN1Q1KNR w q - 21 24')
# Board_value is:  6
# Game 39 finished.
# Board('rnbqkbn1/1p1ppp1p/5B2/p1p5/4P3/NP6/P1PP1PPP/R2QKBNR w KQq - 15 16')
# Board_value is:  6
# Game 40 finished.
# Board('1nb1kbn1/2rp1p2/1p3B2/2p1p3/p7/PP2PNp1/2PP1PP1/RN1Q1K1R b - - 7 28')
# Board_value is:  11
# Game 41 finished.
# Board('5k2/5p2/8/p1p5/P1B3p1/6P1/3P2K1/R3n3 w - - 38 76')
# Board_value is:  4
# Game 42 finished.
# Board('rnb1kbnB/1pqppp2/p7/2p5/7p/1P6/P1PPPPPP/RN1QKBNR w KQq - 14 14')
# Board_value is:  6
# Game 43 finished.
# Board('rnb1kbn1/1pqpppBp/p7/2p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 44 finished.
# Board('1nb1kbn1/1p1ppp2/r1q5/2p1B3/p6p/NP2P3/P1PP1P1P/R2QKBNR w KQ - 8 28')
# Board_value is:  5
# Game 45 finished.
# Board('rnb2bn1/1p1pp3/5Bk1/2p5/4P3/PP4P1/N1PP1PP1/RN1Q1K1R w - - 7 26')
# Board_value is:  15
# Game 46 finished.
# Board('rnb1kbnB/1pqppp2/p7/2p5/7p/NP6/P1PPPPPP/R2QKBNR w KQq - 10 18')
# Board_value is:  6
# Game 47 finished.
# Board('1nb1Nbn1/3ppp1B/1p6/5q2/4Pk1p/N7/P2P1P1P/R4KR1 b - - 27 66')
# Board_value is:  -2
# Game 48 finished.
# Board('1n3bn1/5pp1/1k1Pp3/rr6/3p4/1P4p1/3P1PP1/RNB2KR1 b - - 15 45')
# Board_value is:  -3
# Game 49 finished.
# Board('rnbqkbn1/1p1ppp1p/p7/2p1B3/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 9 11')
# Board_value is:  6
# Game 50 finished.
# Board('rnbqkbn1/2pppp2/8/6r1/4P2p/1P6/N1PP1PPP/RN1Q1KR1 b - - 7 28')
# Board_value is:  -4
# Game 51 finished.
# Board('rnb2bn1/3pp3/1p3Bk1/p1p5/P6p/1P2P1P1/N1PP1PP1/RN1Q1KR1 w - - 12 43')
# Board_value is:  13
# Game 52 finished.
# Board('1nbqkbnr/1ppppppp/1r6/P7/8/4P3/2PP1PPP/RN1Q1KNR b k - 7 10')
# Board_value is:  -6
# Game 53 finished.
# Board('rnb1kbnB/3ppp2/Bp2q3/2p5/p3P2p/1P6/P1PPNP1P/RN1Q1K1R b q - 10 19')
# Board_value is:  5
# Game 54 finished.
# Board('rnbqkbn1/1p1pppB1/p7/2p5/7p/NP6/P1PPPPPP/R2QKBNR w KQq - 12 19')
# Board_value is:  6
# Game 55 finished.
# Board('1nB1k3/3p1p2/1p2p2n/2p5/4P2p/1P6/N1PP2PP/1N1Q1KR1 w - - 10 34')
# Board_value is:  17
# Game 56 finished.
# Board('rn3bn1/2q1pp1B/1pkp1B2/7p/4P3/NP6/P1PPNPPP/R2Q1KR1 w - - 11 38')
# Board_value is:  11
# Game 57 finished.
# Board('1nb1k1n1/1r1p1p2/1p2p3/2p1B3/p3P2p/NP3Kb1/P1PPNP1P/R2QR3 w - - 32 52')
# Board_value is:  11
# Game 58 finished.
# Board('1nbqkbn1/1p1ppp2/r4B2/p1p5/7p/1P6/P1PPPPPP/RN1QKBNR w KQ - 30 23')
# Board_value is:  6
# Game 59 finished.
# Board('1nb1B3/3p1n2/rp3k2/2p5/p3P2p/NPN5/P1P2PPP/R1KQ2R1 w - - 13 38')
# Board_value is:  16
# Game 60 finished.
# Board('1n3bnr/4pp1B/1pkp4/r7/7p/NPP5/P1P1KP1P/R5Q1 w - - 12 49')
# Board_value is:  2
# Game 61 finished.
# Board('1nb1k3/3pbp2/1pB2B1n/2p1p3/p6p/NPN1P3/P1PP1PPP/R2Q1K1R b - - 8 30')
# Board_value is:  20
# Game 62 finished.
# Board('rnb2bn1/3q2k1/pp1ppp2/P1p2p2/4P2p/NP1P1B2/2P2PrP/R2Q1KR1 b - - 7 31')
# Board_value is:  -7
# Game 63 finished.
# Board('1n6/3p4/5bkn/p1p2r2/P6p/1P5P/5PK1/1N6 w - - 20 74')
# Board_value is:  -11
# Game 64 finished.
# Board('rnb1kbn1/1pqppp1p/5B2/p1p5/2B5/1P2P3/P1PPNPPP/RN1Q1KR1 w q - 13 19')
# Board_value is:  6
# Game 65 finished.
# Board('8/8/1R6/5k2/p7/N5KP/P1P5/8 w - - 22 100')
# Board_value is:  10
# Game 66 finished.
# Board('2b2k2/3p2r1/8/5p2/n6p/Pr5P/3N1P2/R6K w - - 20 63')
# Board_value is:  -8
# Game 67 finished.
# Board('rnbqkbn1/3ppp2/1p3B2/2p5/p1B4p/NPN1P3/P1PP1PPP/R2Q1K1R b q - 7 34')
# Board_value is:  6
# Game 68 finished.
# Board('rnb1kbn1/1pqppp2/p7/2p1B3/7p/1P6/P1PPPPPP/RN1QKBNR w KQq - 14 14')
# Board_value is:  6
# Game 69 finished.
# Board('rnb1kbn1/1pqpppBp/p7/2p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 70 finished.
# Board('rnbqkbn1/1p1ppp2/8/p1p1B3/7p/1P6/P1PPPPPP/RN1QKBNR b KQq - 15 16')
# Board_value is:  6
# Game 71 finished.
# Board('rnb1kbn1/1pqpppBp/p7/2p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 72 finished.
# Board('rnb1N1n1/3p3k/1p2p3/2p1p3/p3P2p/NP4b1/PRPP1P2/3Q1K2 b - - 21 54')
# Board_value is:  2
# Game 73 finished.
# Board('rnb1kbn1/3p1p2/pp6/P1p1p1Bp/2B5/1P2P3/4NPPP/RN1q1KR1 w q - 0 21')
# Game 74 finished.
# Board('rnb1kbn1/1pqpppBp/p7/2p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 75 finished.
# Board('rnb1kbn1/1pqpppB1/p7/2p5/7p/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 76 finished.
# Board('1n4n1/3kpp2/1p6/P1pN4/P2Pb3/4b2p/2P2P1P/RN1Q1K2 b - - 8 67')
# Board_value is:  9
# Game 77 finished.
# Board('1n3bn1/3B1p2/8/p1pP4/4k2p/N3P3/Pr1P1P1K/7R w - - 24 74')
# Board_value is:  -2
# Game 78 finished.
# Board('rnb1kbn1/1pqpppBp/p7/2p5/8/NP6/P1PPPPPP/R2QKBNR w KQq - 15 18')
# Board_value is:  6
# Game 79 finished.
# Board('rn1Q1k2/5n2/1p2p3/p4b2/4P2P/bPN1p3/P1P2PP1/R4KR1 b - - 9 48')
# Board_value is:  8
# Game 80 finished.
# Board('1nQ1k1n1/3p1p2/1p1b1B2/2pBp3/7p/P7/1p3P1P/R4K1R b - - 0 49')
# Game 81 finished.
# Board('rnbqkbn1/1p1ppp2/p7/2p1B3/7p/1P6/P1PPPPPP/RN1QKBNR w KQq - 16 15')
# Board_value is:  6
# Game 82 finished.
# Board('1nb1kb2/1q1ppp2/1p5n/p1p1B3/7p/NPN1P3/P1PP1P1P/R2Q1K1R w - - 20 35')
# Board_value is:  7
# Game 83 finished.
# Board('1nb2bn1/3ppk2/1p3q2/2p2r2/p3P2p/N1N5/P1PP4/R2QK3 b - - 11 40')
# Board_value is:  -8
# Game 84 finished.
# Board('2b5/4k3/4p1n1/2p5/1p6/NP5P/3P1P2/5K2 w - - 53 84')
# Board_value is:  -2
# Game 85 finished.
# Board('rnb1kbnB/1pqppp1p/8/p1p5/P7/1P6/2PPPPPP/RN1QKBNR w KQq - 15 15')
# Board_value is:  6
# Game 86 finished.
# Board('2b2k2/4rn2/1p1pp3/P3n3/3pP2P/b7/N1PP1PP1/R2Q1KR1 b - - 16 51')
# Board_value is:  8
# Game 87 finished.
# Board('1nb1kbn1/3p1p2/rp2pB2/2p5/p3P2p/PP4P1/N1PP1PP1/RN1Q1KR1 w - - 10 28')
# Board_value is:  12
# Game 88 finished.
# Board('rnb1kbn1/1pqppp2/B7/P1p1B2p/4P3/1P6/2PP1PPP/RN1Q1KNR w q - 15 19')
# Board_value is:  7
# Game 89 finished.
# Board('rn2kr2/3ppp2/Bp3b2/P1p2p2/4R2p/N1N1P2P/P1PP1P2/R2Q1K2 w - - 15 30')
# Board_value is:  12
# Game 90 finished.
# Board('8/6p1/2k1Kp2/4n3/3PP2p/4r3/8/8 b - - 13 111')
# Board_value is:  -9
# Game 91 finished.
# Board('rnb1kbn1/3ppp2/1p6/2p1B2p/p1B4q/NP2P3/P1PPNPPP/R2Q1K1R w q - 18 30')
# Board_value is:  6
# Game 92 finished.
# Board('1nB1kbn1/3ppp2/1p6/p1p5/7p/NP2q3/P1PP1P1P/R2Q1KNR w - - 8 27')
# Board_value is:  9
# Game 93 finished.
# Board('1n4nR/2kp1p2/4p3/2p1B2Q/p3B3/N6p/P1PP1P2/R4K2 b - - 10 71')
# Board_value is:  20
# Game 94 finished.
# Board('rnb1kbn1/1pqpppBp/p7/2p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 95 finished.
# Board('rnbqkbnB/1p1ppp2/8/p1p5/7p/1P6/P1PPPPPP/RN1QKBNR w KQq - 16 16')
# Board_value is:  6
# Game 96 finished.
# Board('rnb1kbn1/1pqpppBp/p7/2p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 97 finished.
# Board('rnbqkbn1/1p1pppBp/8/p1p5/8/1P6/P1PPPPPP/RN1QKBNR w KQq - 15 14')
# Board_value is:  6
# Game 98 finished.
# Board('1n3bnR/1rk2p2/1p2p3/2p1B3/p7/PP1PP2P/N4PBP/RN3K2 b - - 12 44')
# Board_value is:  10
# Game 99 finished.
# Board('rnbqkbn1/1p1pppB1/p7/2p5/4P2p/1P6/P1PP1PPP/RN1QKBNR w KQq - 15 15')
# Board_value is:  6
# Game 100 finished.
# All games completed.

# %%
epochs= 50
batch_size = 1
learning_rate = 1e-2
history = train_model(model, epochs, batch_size, learning_rate)
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x7d5f9cce75b0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# Exception ignored in: <function _xla_gc_callback at 0x7d5f9cce75b0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# Exception ignored in: <function _xla_gc_callback at 0x7d5f9cce75b0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# Exception ignored in: <function _xla_gc_callback at 0x7d5f9cce75b0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# Exception ignored in: <function _xla_gc_callback at 0x7d5f9cce75b0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# Exception ignored in: <function _xla_gc_callback at 0x7d5f9cce75b0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# Epoch 1/50
# 5794/5794 [==============================] - 55s 9ms/step - loss: 7.0707 - policy_output_loss: 7.0483 - value_output_loss: 0.0224 - policy_output_accuracy: 0.0017 - value_output_mse: 0.0224 - val_loss: 6.2762 - val_policy_output_loss: 6.2548 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 2/50
# 5794/5794 [==============================] - 52s 9ms/step - loss: 6.0307 - policy_output_loss: 6.0085 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0012 - value_output_mse: 0.0222 - val_loss: 5.9894 - val_policy_output_loss: 5.9681 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 3/50
# 5794/5794 [==============================] - 52s 9ms/step - loss: 5.8993 - policy_output_loss: 5.8772 - value_output_loss: 0.0221 - policy_output_accuracy: 0.0017 - value_output_mse: 0.0221 - val_loss: 5.9470 - val_policy_output_loss: 5.9257 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 4/50
# 5794/5794 [==============================] - 55s 9ms/step - loss: 5.8732 - policy_output_loss: 5.8511 - value_output_loss: 0.0221 - policy_output_accuracy: 6.9037e-04 - value_output_mse: 0.0221 - val_loss: 5.9324 - val_policy_output_loss: 5.9109 - val_value_output_loss: 0.0216 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0216
# Epoch 5/50
# 5794/5794 [==============================] - 55s 9ms/step - loss: 5.8674 - policy_output_loss: 5.8452 - value_output_loss: 0.0222 - policy_output_accuracy: 5.1778e-04 - value_output_mse: 0.0222 - val_loss: 5.9277 - val_policy_output_loss: 5.9064 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 6.9013e-04 - val_value_output_mse: 0.0213
# Epoch 6/50
# 5794/5794 [==============================] - 52s 9ms/step - loss: 5.8657 - policy_output_loss: 5.8435 - value_output_loss: 0.0222 - policy_output_accuracy: 8.6296e-04 - value_output_mse: 0.0222 - val_loss: 5.9259 - val_policy_output_loss: 5.9046 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 7/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8636 - policy_output_loss: 5.8414 - value_output_loss: 0.0222 - policy_output_accuracy: 5.1778e-04 - value_output_mse: 0.0222 - val_loss: 5.9303 - val_policy_output_loss: 5.9090 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 8/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8642 - policy_output_loss: 5.8420 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0014 - value_output_mse: 0.0222 - val_loss: 5.9304 - val_policy_output_loss: 5.9090 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 9/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8630 - policy_output_loss: 5.8409 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0012 - value_output_mse: 0.0222 - val_loss: 5.9341 - val_policy_output_loss: 5.9127 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 10/50
# 5794/5794 [==============================] - 52s 9ms/step - loss: 5.8635 - policy_output_loss: 5.8413 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0010 - value_output_mse: 0.0222 - val_loss: 5.9341 - val_policy_output_loss: 5.9128 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 11/50
# 5794/5794 [==============================] - 56s 10ms/step - loss: 5.8630 - policy_output_loss: 5.8409 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0012 - value_output_mse: 0.0222 - val_loss: 5.9264 - val_policy_output_loss: 5.9051 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0117 - val_value_output_mse: 0.0213
# Epoch 12/50
# 5794/5794 [==============================] - 59s 10ms/step - loss: 5.8627 - policy_output_loss: 5.8405 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0012 - value_output_mse: 0.0222 - val_loss: 5.9306 - val_policy_output_loss: 5.9093 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 13/50
# 5794/5794 [==============================] - 56s 10ms/step - loss: 5.8639 - policy_output_loss: 5.8417 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0017 - value_output_mse: 0.0222 - val_loss: 5.9313 - val_policy_output_loss: 5.9100 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 14/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8637 - policy_output_loss: 5.8416 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0014 - value_output_mse: 0.0222 - val_loss: 5.9307 - val_policy_output_loss: 5.9093 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 15/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8630 - policy_output_loss: 5.8408 - value_output_loss: 0.0222 - policy_output_accuracy: 6.9037e-04 - value_output_mse: 0.0222 - val_loss: 5.9234 - val_policy_output_loss: 5.9021 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 16/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8624 - policy_output_loss: 5.8403 - value_output_loss: 0.0222 - policy_output_accuracy: 6.9037e-04 - value_output_mse: 0.0222 - val_loss: 5.9343 - val_policy_output_loss: 5.9129 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 17/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8636 - policy_output_loss: 5.8414 - value_output_loss: 0.0222 - policy_output_accuracy: 8.6296e-04 - value_output_mse: 0.0222 - val_loss: 5.9293 - val_policy_output_loss: 5.9080 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 18/50
# 5794/5794 [==============================] - 58s 10ms/step - loss: 5.8638 - policy_output_loss: 5.8416 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0017 - value_output_mse: 0.0222 - val_loss: 5.9313 - val_policy_output_loss: 5.9100 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 6.9013e-04 - val_value_output_mse: 0.0213
# Epoch 19/50
# 5794/5794 [==============================] - 55s 10ms/step - loss: 5.8635 - policy_output_loss: 5.8414 - value_output_loss: 0.0222 - policy_output_accuracy: 8.6296e-04 - value_output_mse: 0.0222 - val_loss: 5.9299 - val_policy_output_loss: 5.9086 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 20/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8640 - policy_output_loss: 5.8418 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0019 - value_output_mse: 0.0222 - val_loss: 5.9270 - val_policy_output_loss: 5.9057 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 21/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8633 - policy_output_loss: 5.8412 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0012 - value_output_mse: 0.0222 - val_loss: 5.9222 - val_policy_output_loss: 5.9008 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 6.9013e-04 - val_value_output_mse: 0.0214
# Epoch 22/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8635 - policy_output_loss: 5.8413 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0014 - value_output_mse: 0.0222 - val_loss: 5.9329 - val_policy_output_loss: 5.9115 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 23/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8636 - policy_output_loss: 5.8414 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0022 - value_output_mse: 0.0222 - val_loss: 5.9261 - val_policy_output_loss: 5.9048 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 24/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8629 - policy_output_loss: 5.8408 - value_output_loss: 0.0222 - policy_output_accuracy: 8.6296e-04 - value_output_mse: 0.0222 - val_loss: 5.9299 - val_policy_output_loss: 5.9086 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 25/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8633 - policy_output_loss: 5.8411 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0016 - value_output_mse: 0.0222 - val_loss: 5.9297 - val_policy_output_loss: 5.9083 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 26/50
# 5794/5794 [==============================] - 54s 9ms/step - loss: 5.8633 - policy_output_loss: 5.8411 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0016 - value_output_mse: 0.0222 - val_loss: 5.9315 - val_policy_output_loss: 5.9101 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 27/50
# 5794/5794 [==============================] - 56s 10ms/step - loss: 5.8640 - policy_output_loss: 5.8418 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0016 - value_output_mse: 0.0222 - val_loss: 5.9280 - val_policy_output_loss: 5.9066 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 28/50
# 5794/5794 [==============================] - 56s 10ms/step - loss: 5.8635 - policy_output_loss: 5.8413 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0012 - value_output_mse: 0.0222 - val_loss: 5.9288 - val_policy_output_loss: 5.9075 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 29/50
# 5794/5794 [==============================] - 55s 9ms/step - loss: 5.8626 - policy_output_loss: 5.8404 - value_output_loss: 0.0222 - policy_output_accuracy: 5.1778e-04 - value_output_mse: 0.0222 - val_loss: 5.9284 - val_policy_output_loss: 5.9070 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 30/50
# 5794/5794 [==============================] - 55s 10ms/step - loss: 5.8631 - policy_output_loss: 5.8409 - value_output_loss: 0.0222 - policy_output_accuracy: 8.6296e-04 - value_output_mse: 0.0222 - val_loss: 5.9292 - val_policy_output_loss: 5.9079 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 31/50
# 5794/5794 [==============================] - 56s 10ms/step - loss: 5.8642 - policy_output_loss: 5.8421 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0014 - value_output_mse: 0.0222 - val_loss: 5.9262 - val_policy_output_loss: 5.9049 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 32/50
# 5794/5794 [==============================] - 55s 9ms/step - loss: 5.8631 - policy_output_loss: 5.8409 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0014 - value_output_mse: 0.0222 - val_loss: 5.9273 - val_policy_output_loss: 5.9059 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0117 - val_value_output_mse: 0.0213
# Epoch 33/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8636 - policy_output_loss: 5.8414 - value_output_loss: 0.0222 - policy_output_accuracy: 8.6296e-04 - value_output_mse: 0.0222 - val_loss: 5.9244 - val_policy_output_loss: 5.9031 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0117 - val_value_output_mse: 0.0213
# Epoch 34/50
# 5794/5794 [==============================] - 58s 10ms/step - loss: 5.8635 - policy_output_loss: 5.8413 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0010 - value_output_mse: 0.0222 - val_loss: 5.9249 - val_policy_output_loss: 5.9036 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 6.9013e-04 - val_value_output_mse: 0.0213
# Epoch 35/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8628 - policy_output_loss: 5.8407 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0010 - value_output_mse: 0.0222 - val_loss: 5.9274 - val_policy_output_loss: 5.9061 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 36/50
# 5794/5794 [==============================] - 58s 10ms/step - loss: 5.8629 - policy_output_loss: 5.8407 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0014 - value_output_mse: 0.0222 - val_loss: 5.9408 - val_policy_output_loss: 5.9193 - val_value_output_loss: 0.0216 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0216
# Epoch 37/50
# 5794/5794 [==============================] - 58s 10ms/step - loss: 5.8629 - policy_output_loss: 5.8408 - value_output_loss: 0.0222 - policy_output_accuracy: 6.9037e-04 - value_output_mse: 0.0222 - val_loss: 5.9274 - val_policy_output_loss: 5.9060 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 38/50
# 5794/5794 [==============================] - 55s 10ms/step - loss: 5.8630 - policy_output_loss: 5.8408 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0010 - value_output_mse: 0.0222 - val_loss: 5.9304 - val_policy_output_loss: 5.9091 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 39/50
# 5794/5794 [==============================] - 55s 10ms/step - loss: 5.8638 - policy_output_loss: 5.8416 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0024 - value_output_mse: 0.0222 - val_loss: 5.9252 - val_policy_output_loss: 5.9039 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 40/50
# 5794/5794 [==============================] - 58s 10ms/step - loss: 5.8631 - policy_output_loss: 5.8409 - value_output_loss: 0.0221 - policy_output_accuracy: 0.0010 - value_output_mse: 0.0221 - val_loss: 5.9251 - val_policy_output_loss: 5.9037 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 41/50
# 5794/5794 [==============================] - 58s 10ms/step - loss: 5.8631 - policy_output_loss: 5.8409 - value_output_loss: 0.0222 - policy_output_accuracy: 6.9037e-04 - value_output_mse: 0.0222 - val_loss: 5.9298 - val_policy_output_loss: 5.9085 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 42/50
# 5794/5794 [==============================] - 55s 10ms/step - loss: 5.8645 - policy_output_loss: 5.8423 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0016 - value_output_mse: 0.0222 - val_loss: 5.9237 - val_policy_output_loss: 5.9023 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 43/50
# 5794/5794 [==============================] - 55s 9ms/step - loss: 5.8628 - policy_output_loss: 5.8407 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0016 - value_output_mse: 0.0222 - val_loss: 5.9285 - val_policy_output_loss: 5.9072 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 44/50
# 5794/5794 [==============================] - 55s 9ms/step - loss: 5.8620 - policy_output_loss: 5.8399 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0022 - value_output_mse: 0.0222 - val_loss: 5.9302 - val_policy_output_loss: 5.9088 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0117 - val_value_output_mse: 0.0214
# Epoch 45/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8632 - policy_output_loss: 5.8410 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0016 - value_output_mse: 0.0222 - val_loss: 5.9265 - val_policy_output_loss: 5.9051 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0117 - val_value_output_mse: 0.0213
# Epoch 46/50
# 5794/5794 [==============================] - 58s 10ms/step - loss: 5.8643 - policy_output_loss: 5.8421 - value_output_loss: 0.0222 - policy_output_accuracy: 6.9037e-04 - value_output_mse: 0.0222 - val_loss: 5.9272 - val_policy_output_loss: 5.9059 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 47/50
# 5794/5794 [==============================] - 57s 10ms/step - loss: 5.8639 - policy_output_loss: 5.8417 - value_output_loss: 0.0222 - policy_output_accuracy: 6.9037e-04 - value_output_mse: 0.0222 - val_loss: 5.9258 - val_policy_output_loss: 5.9044 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# Epoch 48/50
# 5794/5794 [==============================] - 56s 10ms/step - loss: 5.8632 - policy_output_loss: 5.8410 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0014 - value_output_mse: 0.0222 - val_loss: 5.9300 - val_policy_output_loss: 5.9086 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0117 - val_value_output_mse: 0.0214
# Epoch 49/50
# 5794/5794 [==============================] - 56s 10ms/step - loss: 5.8627 - policy_output_loss: 5.8405 - value_output_loss: 0.0222 - policy_output_accuracy: 0.0012 - value_output_mse: 0.0222 - val_loss: 5.9265 - val_policy_output_loss: 5.9051 - val_value_output_loss: 0.0214 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0214
# Epoch 50/50
# 5794/5794 [==============================] - 58s 10ms/step - loss: 5.8640 - policy_output_loss: 5.8418 - value_output_loss: 0.0222 - policy_output_accuracy: 5.1778e-04 - value_output_mse: 0.0222 - val_loss: 5.9255 - val_policy_output_loss: 5.9042 - val_value_output_loss: 0.0213 - val_policy_output_accuracy: 0.0000e+00 - val_value_output_mse: 0.0213
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

def plot_policy_and_value(history):
    # Plot for Policy: Accuracy vs. Loss
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['policy_output_accuracy'], label='Train')
    plt.plot(history.history['val_policy_output_accuracy'], label='Validation')
    plt.title('Policy Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    # Plot for Value: MSE vs. Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['value_output_mse'], label='Train')
    plt.plot(history.history['val_value_output_mse'], label='Validation')
    plt.title('Value MSE')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()


# Assuming 'history' is the variable holding the output from the model.fit() call
plot_policy_and_value(history)
